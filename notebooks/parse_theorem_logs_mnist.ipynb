# %%
# %matplotlib inline

import os

import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.animation as animation

from IPython.display import HTML
from IPython import display

# %%
graphs = []
log_path = "/home/datta/lab/Rethinking-Binarized-Neural-Network-Optimization/logs/theorem_mnist_logs/"
for file in os.listdir(log_path):
    df = pd.read_json(log_path+file)
    df = df[[1, 2]]
    df['label'] = file.split(".json")[0]
    graphs.append(df)

# %%
def best_acc(df):
    return df[2].max()
sorted_graphs = sorted(graphs, key = best_acc, reverse=True)

# %%
# %matplotlib inline
fig, ax = plt.subplots(1, 1)
_ = plt.rcParams['figure.figsize'] = (15, 5)

for df in sorted_graphs:
    _ = ax.plot(df[1], df[2])
    print(df['label'][0])
_ = plt.ylim(0.8, 1)

_ = plt.title("Training on MNIST")
_ = plt.xlabel("Number of Epochs")
_ = plt.ylabel("Training Accuracy")
_ = plt.grid(True)
_ = ax.legend(['Random + Adam lr=0.01', 'Glorot + SGD lr=1', 'Scaled Glorot + SGD lr=0.01',
               'Glorot + SGD lr=0.01',  'Random + SGD lr=0.01'], loc=4)

"""
_ = ax.legend(['Adam init=random lr=0.01', 'SGD init=glorot lr=1',
               'SGD init=glorot lr=0.01', 'SGD init=glorot lr=0.01 scaled weights', 'SGD init=random lr=0.01'], loc=4)
"""
#_ = ax.legend(legend, loc = 4)
# Out:
# adam
# sgd 1
# sgd 0.01 scaled weights
# sgd 0.01
# sgd
# "\n_ = ax.legend(['Adam init=random lr=0.01', 'SGD init=glorot lr=1',\n               'SGD init=glorot lr=0.01', 'SGD init=glorot lr=0.01 scaled weights', 'SGD init=random lr=0.01'], loc=4)\n"

# %%
fig.savefig("/home/datta/lab/Rethinking-Binarized-Neural-Network-Optimization/plots/theorem_mnist.png")
